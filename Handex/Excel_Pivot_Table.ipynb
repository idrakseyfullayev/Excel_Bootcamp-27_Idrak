# %% [markdown]
# ## Excel Pivot Table  - Design menyusu

# %% [markdown]
# ### ✅ **Design Menyusu → Pivot Table Dizayn Ayarları**
#
#
#
# #### **1. Report Layout → Hesabat Quruluşu**
#
# | Funksiya                    | Nə edir?                                                                 | Nümunə                                                      |
# | --------------------------- | ------------------------------------------------------------------------ | ----------------------------------------------------------- |
# | `Show in Compact Form`      | Sətirləri **yığcam** formada göstərir. Default görünüşdür.               | Kateqoriya və alt kateqoriyalar **eyni sütunda** göstərilir |
# | `Show in Outline Form`      | Sətirləri **ayrı-ayrı sütunlarda** göstərir.                             | Kateqoriya ayrı, alt kateqoriya ayrı sütunda olur           |
# | `Show in Tabular Form`      | Hər bir səviyyə üçün **fərqli sətir göstərir**, görünüş **çox açıqdır**  | Cədvəl tipində görünüş alınır                               |
# | `Repeat All Item Labels`    | Alt səviyyələrdə **eyni kateqoriya adını təkrar göstərir**               | Boş hüceyrə əvəzinə üst səviyyə adı göstərilir              |
# | `Do Not Repeat Item Labels` | Təkrarlanmanı **söndürür**, eyni kateqoriya adını yalnız 1 dəfə göstərir | Alt səviyyələrdə boş hüceyrələr görünə bilər                |
#
# ---
#
# #### **2. Subtotals → Alt Cəmlər**
#
# | Funksiya                       | Nə edir?                                     |
# | ------------------------------ | -------------------------------------------- |
# | `Do Not Show Subtotals`        | Alt cəmləri **gizlədir**                     |
# | `Show all Subtotals at Bottom` | Alt cəmləri **qrupların sonunda** göstərir   |
# | `Show all Subtotals at Top`    | Alt cəmləri **qrupların əvvəlində** göstərir |
#
# ---
#
# #### **3. Grand Totals → Ümumi Cəmlər**
#
# | Funksiya                   | Nə edir?                                                        |
# | -------------------------- | --------------------------------------------------------------- |
# | `Off for Rows and Columns` | Həm **sətir**, həm də **sütunlar** üçün ümumi cəmi **gizlədir** |
# | `On for Rows and Columns`  | Həm sətir, həm də sütun üçün **ümumi cəmi göstərir**            |
# | `On for Rows Only`         | **Yalnız sətirlər** üçün ümumi cəmi göstərir                    |
# | `On for Columns Only`      | **Yalnız sütunlar** üçün ümumi cəmi göstərir                    |
#
# ---
#
# #### **4. Blank Rows → Boş Sətirlər**
#
# | Funksiya                            | Nə edir?                                                |
# | ----------------------------------- | ------------------------------------------------------- |
# | `Insert Blank Line After Each Item` | Hər əsas kateqoriyadan sonra **1 boş sətir əlavə edir** |
# | `Remove Blank Line After Each Item` | Boş sətirləri **gizlədir**                              |
#
# ---
#
# #### **5. PivotTable Styles → Pivot Cədvəl Üslubları**
#
# | Funksiya                       | Nə edir?                                                          |
# | ------------------------------ | ----------------------------------------------------------------- |
# | `PivotTable Style Gallery`     | Fərqli dizayn üslubları təklif edir (rəngli, zolaqlı, sadə və s.) |
# | `Banded Rows`                  | Zolaqlı sətirlər göstərir (rənglərlə növbəli sətirlər)            |
# | `Banded Columns`               | Zolaqlı sütunlar göstərir                                         |
# | `Row Headers`                  | Sətir başlıqlarına stil tətbiq edir                               |
# | `Column Headers`               | Sütun başlıqlarına stil tətbiq edir                               |
# | `First Column` / `Last Column` | Əvvəlki/son sütunlara vurğulama tətbiq edir (bold, rəng və s.)    |
#
# ---

# %% [markdown]
# ## ✅ **PivotTable Analyze → Options → Layout & Format**
#
# 📍 **Pivot Table-in görünüşünü və məlumat formatını tənzimləməyə imkan verir**

# %% [markdown]
# ### 🔷 **Layout (Quruluş Ayarları)**
#
# | Funksiya                                  | Nə edir?                                                                          | Qeyd / Nümunə                                            |
# | ----------------------------------------- | --------------------------------------------------------------------------------- | -------------------------------------------------------- |
# | `Merge and center cells with labels`      | Eyni səviyyədəki başlıqları **bir hüceyrəyə birləşdirir** və **mərkəzləşdirir**   | Boş hüceyrələri mərkəzlə birləşdirilmiş formada göstərir |
# | `Indent row labels`                       | Sətir etiketlərinin (labels) **boşluqla içəri çəkilməsini** təmin edir            | Alt səviyyələr daha içəri göstərilir                     |
# | `Display fields in report filter area:`   | Report Filter bölməsində sahələrin necə göstəriləcəyini seçir                     | Alt-üst və ya yan-yana göstərmə variantları              |
# | - `Down, Then Over`                       | Report Filter-ləri **şaquli** şəkildə (alt-alta) göstərir                         |                                                          |
# | - `Over, Then Down`                       | Report Filter-ləri **üfüqi** şəkildə (yan-yana) göstərir                          |                                                          |
# | `Number of fields to display per column:` | Report Filter sahələrini **hər sütunda neçə dənə göstərməli** olduğunu təyin edir | 2 yazsaq, hər sütunda 2 filter görünər                   |
#
# ---
#
# ### 🔷 **Format (Formatlaşdırma Ayarları)**
#
# | Funksiya                             | Nə edir?                                                                           | Qeyd / Nümunə                                       |
# | ------------------------------------ | ---------------------------------------------------------------------------------- | --------------------------------------------------- |
# | `For empty cells show:`              | Boş hüceyrələrin yerinə **nə göstəriləcəyini** seçmək olar                         | Məsələn, "0" yazsan boş yerə 0 çıxar                |
# | `Autofit column widths on update`    | Pivot yenilənəndə sütun enini **avtomatik uyğunlaşdırır**                          | Əgər işarəlisə → yenilənmədə sütun eni dəyişə bilər |
# | `Preserve cell formatting on update` | Pivot yenilənəndə **əlavə etdiyin formatlar (rəng, font)** silinməsin deyə qoruyur | Məsələn, rəng vermisənsə, yeniləndikdə silinməsin   |
#
# ---

# %% [markdown]
# ## ✅ **PivotTable Analyze → Options → Totals & Filters**
#
# 📍 **Alt cəmlərin və filtrlərin göstərilməsini tənzimləyir**

# %% [markdown]
# ### 🔷 **Totals (Ümumi və Alt Cəmlər)**
#
# | Funksiya                           | Nə edir?                                                       | Qeyd / Nümunə                                              |
# | ---------------------------------- | -------------------------------------------------------------- | ---------------------------------------------------------- |
# | `Show grand totals for rows`       | **Sətirlər üzrə ümumi cəmi** göstərir                          | Üfüqi istiqamətdə **ümumi nəticə sətiri** əlavə edir       |
# | `Show grand totals for columns`    | **Sütunlar üzrə ümumi cəmi** göstərir                          | Düşey istiqamətdə **ümumi nəticə sütunu** əlavə edir       |
# | `Allow multiple filters per field` | Hər bir sahəyə **birdən çox filter** tətbiq etməyə icazə verir | Eyni sahədə "Apple" və "Orange" eyni anda filterlənə bilər |
#
# ---
#
# ### 🔷 **Filters (Filtr Ayarları)**
#
# | Funksiya                          | Nə edir?                                                                            | Qeyd / Nümunə                                              |
# | --------------------------------- | ----------------------------------------------------------------------------------- | ---------------------------------------------------------- |
# | `Use custom lists when sorting`   | Filtrləmə və sıralama zamanı **Excel-in daxili siyahılarına əsaslanaraq sıralayır** | Məsələn, "Bazar ertəsi, Çərşənbə..." kimi özəl sıralamalar |
# | `Sort A to Z` və ya `Sort Z to A` | Əsas sahələri A-Z və ya Z-A görə sıralayır                                          | Manual dəyişdirmə ilə fərqlidir                            |

# %% [markdown]
# ## ✅ **PivotTable Analyze → Options → Display**
#
# 📍 **Pivot Table-də sahələrin və düymələrin necə görünəcəyini tənzimləyir**

# %% [markdown]
# ### 🔷 **Display (Görünüş Ayarları)**
#
# | Funksiya                                                             | Nə edir?                                                                                                      | Qeyd / Nümunə                                                                       |
# | -------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------- |
# | `Show expand/collapse buttons`                                       | **+ və – düymələrini** göstərir/gizlədir – qrupları açıb-bağlamaq üçün                                        | Sətir və sütun sahələrinin yanında **+ / -** işarələri görünər                      |
# | `Show contextual tooltips`                                           | Hüceyrə üzərinə gələndə **açıqlayıcı ipucu (tooltip)** çıxar                                                  | Məlumatı daha rahat başa düşmək üçün əlavə köməkçi yazı                             |
# | `Show properties in tooltips`                                        | Tooltip-lərdə **daha geniş məlumat (property)** göstərilməsinə imkan verir                                    | Əlavə meta-məlumat çıxar (məsələn, "Product ID", "Category")                        |
# | `Show field captions and filter drop downs`                          | **Başlıqlar və filter oxlarını** göstərir                                                                     | Sütun başlıqlarında **filterləmək üçün ox** görünər                                 |
# | `Classic PivotTable layout (enables dragging of fields in the grid)` | Pivot Table-i **klassik görünüşə** salır – sahələri birbaşa cədvələ **sürüşdürərək əlavə etməyə** imkan verir | Pivot sahələrini adətən sağ paneldən yox, birbaşa grid üzərində tənzimləyə bilərsən |
# | `Display field captions and filter drop downs`                       | **Field adlarını və filter menyusunu** göstərir/gizlədir                                                      | Sütun adları və yanındakı filter oxları görünməyə bilər                             |

# %% [markdown]
# ## ✅ **PivotTable Analyze → Options → Printing**
#
# 📍 **Pivot Cədvəlin çap zamanı necə göründüyünü tənzimləyir**

# %% [markdown]
# ### 🔷 **Printing (Çap Ayarları)**
#
# | Funksiya                                       | Nə edir?                                                                                     | Qeyd / Nümunə                                                                |
# | ---------------------------------------------- | -------------------------------------------------------------------------------------------- | ---------------------------------------------------------------------------- |
# | `Print expand/collapse buttons when displayed` | Əgər Pivot Table-də **+ / – düymələri aktivdirsə**, çap zamanı da onları göstərir            | Məsələn, çap faylında istifadəçi hansı hissələrin açıq/qapalı olduğunu görər |
# | `Repeat row labels on each printed page`       | Pivot Table **bir neçə səhifəyə bölünübsə**, **sətir başlıqları hər səhifədə təkrar edilir** | Oxunurluğu artırır – hər səhifədə eyni başlıq görünür                        |

# %% [markdown]
# ## ✅ PivotTable Analyze → Options → Data & Alt Text
#
# - 📍 **Pivot cədvəlinin məlumatlarla necə işlədiyini tənzimləyir**
# - 📍 **Əlçatanlıq (Accessibility) üçün istifadə olunur – Pivot Table-ə təsvir əlavə etməyə imkan verir**

# %% [markdown]
# ### 🔷 **Data (Məlumat Ayarları)**
#
# | Funksiya                               | Nə edir?                                                                                | Qeyd / Nümunə                                        |
# | -------------------------------------- | --------------------------------------------------------------------------------------- | ---------------------------------------------------- |
# | `Save source data with file`           | Pivot Table-in **orijinal data mənbəyini faylla birlikdə yadda saxlayır**               | Faylı başqa kompyuterdə açsan belə Pivot işləyəcək   |
# | `Refresh data when opening the file`   | Excel faylı **açılan zaman Pivot Table avtomatik yenilənir**                            | Məlumatlar dəyişibsə, avtomatik təzə datanı yükləyir |
# | `Number of items to retain per field:` | Pivot Table-də əvvəlki dəyərlərin **neçə dənəsini yadda saxlamalı olduğunu** təyin edir |                                                      |
# | - `Automatic`                          | Excel özü qərar verir                                                                   | Adətən default seçimdir                              |
# | - `None`                               | **Köhnə dəyərləri tamamilə silir**, sadəcə aktiv olanları saxlayır                      | Süzgəc (filter) siyahısında artıq dəyərlər görünməz  |
# | - `Max`                                | İstədiyin qədər əvvəlki dəyəri saxlayır (məsələn, 50)                                   | Nadir hallarda istifadə olunur                       |
#
# ---
#
# ### 🔷 **Alt Text (Alternativ Mətn)**
#
# | Sahə          | Nə edir?                                                            | Qeyd / Nümunə                                                                  |
# | ------------- | ------------------------------------------------------------------- | ------------------------------------------------------------------------------ |
# | `Title`       | Pivot Table üçün **qısa başlıq** yazılır                            | Məsələn: "Satış Hesabatı – 2024"                                               |
# | `Description` | Pivot Table-in nə göstərdiyini izah edən **ətraflı təsvir** verilir | Əlilliyi olan istifadəçilər üçün vacibdir – ekran oxuyucu bu mətni səsləndirir |
#
#
#
# Bu bölmə xüsusilə **əlçatanlıq (accessibility)** məqsədi ilə hazırlanıb – ekran oxuyucular, görmə məhdudiyyətli istifadəçilər üçün vacibdir.
#
#
#
# Hazırda **Options menyusundakı bütün bölmələri** tamamladıq:
#
# * Layout & Format
# * Totals & Filters
# * Display
# * Printing
# * Data
# * Alt Text

# %% [markdown]
# ## ✅ **PivotTable Analyze → Options → Show Report Filter Pages**
#
# 📍 **Report Filter-də seçilmiş sahənin hər bir elementi üçün ayrıca Pivot Sheet yaradır**

# %% [markdown]
# ### 🔷 **Nə edir?**
#
# | Funksiya                   | Nə edir?                                                                                      | Qeyd / Nümunə                                                                       |
# | -------------------------- | --------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------- |
# | `Show Report Filter Pages` | Report Filter-ə qoyulmuş sahənin **hər bir unikal dəyəri üçün ayrıca Pivot səhifəsi** yaradır | Məsələn: "Region" filterindəsə → "East", "West", "South" üçün 3 ayrı səhifə yaranır |
#
# ---
#
# ### 🔷 **Necə işləyir?**
#
# 1. Pivot Table-də **Report Filter** sahəsinə (məsələn, "Region") bir sahə əlavə et.
# 2. **PivotTable Analyze → Options (yuxarı lent menyusu)** bölməsinə keç.
# 3. **Show Report Filter Pages** düyməsini kliklə.
# 4. Açılan pəncərədə **hansı sahəyə görə səhifələr yaradılacağını** seç (Report Filter-də olan sahələr göstərilir).
# 5. OK kliklə → Excel avtomatik olaraq **hər bir dəyər üçün ayrıca yeni sheet** yaradır və həmin filtrlə Pivot Table qurur.
#
# ---
#
# ### 🔎 **Faydalılığı**
#
# | İstifadə Sahəsi                      | Faydası                                                            |
# | ------------------------------------ | ------------------------------------------------------------------ |
# | Bölgələr üzrə hesabatlar             | Hər bölgə üçün **ayrı-ayrı Pivot hesabatı** yaratmaq üçün idealdır |
# | Satıcı/satış nümayəndəsi üzrə bölmə  | Hər nümayəndənin satış hesabatı üçün **avtomatik səhifə** yaratmaq |
# | İllik / Aylıq / Məhsul üzrə bölmələr | Zaman və məhsul əsaslı pivotlar yaratmaq                           |

# %% [markdown]
# ## ✅ `GETPIVOTDATA` funksiyası
#
# 📍 **Pivot Table-dən spesifik dəyəri çəkmək üçün istifadə olunur**

# %% [markdown]
# ### 🔷 **Sintaksis:**
#
# `
# =GETPIVOTDATA(data_field, pivot_table, [field1, item1], [field2, item2], ...)
# `
#
# | Parametr           | İzah                                                              |
# | ------------------ | ----------------------------------------------------------------- |
# | `data_field`       | Hansı **hesablanmış dəyəri** çəkmək istəyirsən? (məs: "Sales")    |
# | `pivot_table`      | Pivot Table-in yerləşdiyi **istənilən hüceyrəyə istinad**         |
# | `field1, item1...` | Filtrləmək istədiyin **sahə adı və həmin sahədəki konkret dəyər** |
#
# ---
#
# ### 🔷 **Nümunə 1:**
#
# Tutaq ki, belə bir Pivot Table var:
#
# | Region | Product | Sum of Sales |
# | ------ | ------- | ------------ |
# | East   | Apple   | 1000         |
# | East   | Banana  | 800          |
# | West   | Apple   | 1200         |
#
# və Pivot Table `A3` hüceyrəsində başlayırsa:
#
# `
# =GETPIVOTDATA("Sales", A3, "Region", "East", "Product", "Apple")
# `
#
# 🔹 **Nəticə:** `1000`
# 📌 Açıq şəkildə **East region və Apple məhsulunun satış dəyərini** çəkir.
#
# ---
#
# ### 🔷 **Nümunə 2: (Yalnız Region səviyyəsində)**
#
# `
# =GETPIVOTDATA("Sales", A3, "Region", "West")
# `
#
# 🔹 **Nəticə:** West region üçün ümumi satış (Apple: 1200)
#
# ---
#
# ### 🔷 **Avtomatik Yaranması:**
#
# Pivot Table-dən bir hüceyrəyə `=` ilə istinad etdikdə, Excel **avtomatik `GETPIVOTDATA` funksiyası** yaradır.
# Əgər bunu istəmirsənsə:
#
# 🔧 **Söndürmək üçün:**
#
# * Ribbon-da: `PivotTable Analyze → Options → Generate GetPivotData` (bu seçimi deaktiv et)
#
# ---
#
# ### 🔷 **Faydaları:**
#
# | Üstünlük                                       | İzaH                                                        |
# | ---------------------------------------------- | ----------------------------------------------------------- |
# | Məlumatlar dəyişsə belə nəticə **dəqiq qalır** | Çünki sahə və filtr adları ilə işləyir, mövqeyə bağlı deyil |
# | Hesabatlarda **dinamik və stabil** istifadə    | Xüsusilə Dashboard və ya avtomatlaşdırılmış cədvəllərdə     |

# %% [markdown]
# ## ✅ **Generate GETPIVOTDATA**
#
# 📍 **Pivot Table-dən məlumat çəkərkən `GETPIVOTDATA` funksiyasının avtomatik yaradılıb-yaradılmayacağını idarə edir**

# %% [markdown]
# ### 🔷 **Bu nədir?**
#
# | Xüsusiyyət              | İzah                                                                                                                |
# | ----------------------- | ------------------------------------------------------------------------------------------------------------------- |
# | `Generate GETPIVOTDATA` | Pivot Table-dən hüceyrəyə `=` ilə istinad etdikdə **avtomatik `GETPIVOTDATA` funksiyası** yazılsın ya yox onu seçir |
# | ✔️ Aktivdirsə           | Avtomatik olaraq `GETPIVOTDATA(...)` funksiyası yazılır                                                             |
# | ❌ Passivdirsə           | Sadəcə hüceyrəyə **normal istinad** yazılır (məs: `=C5`)                                                            |
#
# ---
#
# ### 🔷 **Harada yerləşir?**
#
# ➡️ **Ribbon menyusunda:**
# `PivotTable Analyze` tab → **(Sol üst küncdə)**
# `Options` qrupu → `Generate GetPivotData` ✔️
#
# ---
#
# ### 🔷 **Necə deaktiv etmək olar?**
#
# 1. Pivot Table-ə daxil ol
# 2. Menyuda `PivotTable Analyze` tabına keç
# 3. `Options` qrupunda **`Generate GetPivotData`** düyməsini tap
# 4. Üzərinə kliklə → ✔️ işarəsi silinsin
#
# 🔄 Artıq `=` ilə Pivot Table-dən istinad etdikdə sadəcə hüceyrə ünvanı çıxacaq, `GETPIVOTDATA` yox.
#
# ---
#
# ### 🔷 **Nümunə:**
#
# | Halı          | Nəticə yazılışı                                             |
# | ------------- | ----------------------------------------------------------- |
# | ✔️ Aktivdirsə | `=GETPIVOTDATA("Sales",$A$3,"Region","East")`               |
# | ❌ Passivdirsə | `=C5` (hansı hüceyrəni klikləmisənsə, birbaşa onu göstərir) |
#
# ---
#
# ### 🔎 **Nə vaxt söndürmək faydalıdır?**
#
# | İstifadə Ssenarisi                       | Tövsiyə                                                                         |
# | ---------------------------------------- | ------------------------------------------------------------------------------- |
# | Sadə hesabatlar, əl ilə istinadlar       | **Söndürmək** daha rahat ola bilər                                              |
# | Dinamik Dashboard, sahə əsaslı hesablama | **Aktiv saxlamaq** daha etibarlıdır (filtrlər dəyişsə belə düzgün nəticə verir) |

# %% [markdown]
# ## ✅ **PivotTable Analyze → Active Field → Field Settings → Subtotals & Filters**
#
# 📍 **Pivot sahələri üçün alt cəmlərin (subtotal) və filtr ayarlarının tənzimlənməsi**

# %% [markdown]
# ### 🔷 **Field Settings nədir?**
#
# | Bölmə            | Təyinatı                                                                                   |
# | ---------------- | ------------------------------------------------------------------------------------------ |
# | `Field Settings` | Pivot Table-də seçilmiş **sahənin necə göstəriləcəyini və hesablama metodunu** tənzimləyir |
#
# ---
#
# ### 🔹 **Subtotals** (Alt cəmlər)
#
# | Seçim       | Açıklama                                                    | Nümunə                                                            |
# | ----------- | ----------------------------------------------------------- | ----------------------------------------------------------------- |
# | `Automatic` | Excel **öz-özünə** uyğun olan subtotal funksiyasını seçir   | Məsələn, “Sum” və ya “Count”                                      |
# | `None`      | Alt cəmlər **göstərilmir**                                  | Sadəcə detallı satırlar görünür                                   |
# | `Custom`    | Özün **hansı funksiyanın tətbiq olunacağını** seçə bilirsən | Məsələn: `Sum`, `Average`, `Max`, `Min`, `Count`, `Product` və s. |
#
# > 🔸 *Bir sahə üçün həm `Sum`, həm `Average` əlavə etmək olur (Custom seçərək)*
#
# ---
#
# ### 🔹 **Filters**
#
# **(Aynı pəncərədə, subtotals aşağısında yerləşir)**
#
# | Seçim                                | Açıklama                                                                          |
# | ------------------------------------ | --------------------------------------------------------------------------------- |
# | `Include new items in manual filter` | Gələcəkdə **yeni dəyərlər əlavə olunarsa**, onlar avtomatik filtrə daxil olsunmu? |
#
# > ✅ İşarələsən – gələcəkdə yeni "Category", "Region" və s. dəyərlər avtomatik görünər
#
# > ❌ İşarələməsən – yeni dəyərlər **əldəki filtre siyahısına daxil edilməz**
#
# ---
#
# ### 🔎 **Nümunə:**
#
# **Sahə:** `Region`
#
# * `Subtotals → Custom → Sum + Average` → Həm cəmi, həm də ortalamasını göstər
# * `Filters → Include new items...` aktivdirsə → Yeni “Central” regionu gələndə avtomatik göstəriləcək
#
# ---
#
# ### 🟩 İstifadə Ssenariləri
#
# | Məqsəd                                | Tövsiyə olunan seçimlər                           |
# | ------------------------------------- | ------------------------------------------------- |
# | Alt cəmləri özün idarə etmək          | `Custom` və funksiyaları seç (Sum, Average və s.) |
# | Gələcək dəyərləri avtomatik göstərmək | `Include new items in manual filter` aktiv olsun  |
# | Göstərişləri sadə saxlamaq            | `Subtotals → None` ilə sadə və təmiz görünüş      |

# %% [markdown]
# ## PivotTable → Analyze → Active Field → Field Settings → Layout & Print

# %% [markdown]
# ### 🔷 **Layout & Print (Quruluş və Çap Ayarları)**
#
# | Funksiya                                             | Nə edir?                                                                     | Qeyd / Nümunə                                              |
# | ---------------------------------------------------- | ---------------------------------------------------------------------------- | ---------------------------------------------------------- |
# | `Show item labels in outline form`                   | Sətir başlıqlarını **outline (kontur) formatında** göstərir                  | Hər səviyyə ayrıca sətirdə göstərilir, klassik görünüş     |
# | `Show item labels in tabular form`                   | Başlıqları **cədvəl formasında (sətir-sütun formatında)** göstərir           | Hər səviyyə eyni sətirdə ayrı-ayrı sütunlarda olur         |
# | `Repeat item labels`                                 | Eyni dəyər bir neçə sətrə aid olduqda, **təkrar göstərir**                   | Əvvəllər boş görünən hüceyrələr təkrarlanır                |
# | `Insert blank line after each item`                  | Hər qrupdan sonra **bir boş sətir** əlavə edir                               | Oxunması asanlaşır, amma vizual boşluq artır               |
# | `Show items with no data`                            | Məlumat olmayan dəyərləri də **göstərir**                                    | Məsələn, bir məhsul satılmayıbsa, o da siyahıda yer alacaq |
# | `Show labels from the next field in the same column` | Alt səviyyə başlıqları **eyni sütunda** göstərilir, əgər bu seçim aktivdirsə | Daha kompakt görünüş üçün                                  |
#
#
#
# ### 🧭 **Haradan Açılır?**
#
# 1. Pivot Table daxilində istədiyin sahənin (məsələn, `Region`) üzərinə klik et.
# 2. **PivotTable Analyze** sekmesine keç.
# 3. **Active Field** qutusundan **Field Settings**-ə kliklə.
# 4. Açılan pəncərədə **Layout & Print** tabına keç.
#
#
#
# Çox gözəl! İndi gəlin **Layout & Print** bölməsindəki `Print` (Çap) ilə bağlı olan seçimin izahını da əlavə edək:
#
# ---
#
# ### 🔷 **Print (Çap Ayarları)**
#
# (Bu seçim də **Layout & Print** tabının içində yer alır)
#
# | Funksiya                            | Nə edir?                                                                   | Qeyd / Nümunə                                            |
# | ----------------------------------- | -------------------------------------------------------------------------- | -------------------------------------------------------- |
# | `Insert page break after each item` | Hər bir **üst səviyyə dəyərindən sonra yeni səhifə** açılmasını təmin edir | Məsələn, hər "Region" üçün ayrıca çap səhifəsi yaradılır |
#
#
#
# ### 📝 İzah:
#
# Bu seçim **çap edərkən** faydalıdır. Əgər Pivot Table-də məsələn “Region” və ya “Category” kimi bir sahə varsa və sən bu sahənin **hər dəyəri üçün ayrıca səhifə** istəyirsənsə, bu seçimi işarələməlisən.
#
# **Nümunə:**
#
# * Region: **North, South, East**
# * Hər biri üçün ayrıca səhifədə çap olunacaq.
